# %%
import os
import time
import json
import numpy as np
import pandas as pd
from getpass import getpass
from openai import OpenAI
import nltk
import spacy
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics.pairwise import cosine_similarity

# Install dependencies (uncomment if needed)
# !pip install openai pandas numpy scikit-learn nltk spacy tqdm sentence-transformers
# !python -m spacy download en_core_web_sm

# Download NLTK resources
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

# Load SpaCy model
try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    print("Downloading SpaCy model...")
    os.system("python -m spacy download en_core_web_sm")
    nlp = spacy.load("en_core_web_sm")

# ✅ Step 1: Set up API Key securely
os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")
client = OpenAI()

# ✅ Step 2: Load and Preprocess Dataset
CSV_FILE = "keywords.csv"
try:
    df = pd.read_csv(CSV_FILE, header=None, names=["keyword"])
    keywords = df["keyword"].tolist()
    print(f"✅ Loaded {len(keywords)} keywords from {CSV_FILE}")
except FileNotFoundError:
    print(f"❌ File not found: {CSV_FILE}")
    exit(1)

# Preprocess keywords
stop_words = set(stopwords.words('english'))

def preprocess_keywords(keywords):
    processed_keywords = []
    for keyword in keywords:
        if not isinstance(keyword, str):
            processed_keywords.append("")
            continue

        doc = nlp(keyword.lower())  # Process keyword with SpaCy
        tokens = [token.text for token in doc if token.is_alpha and token.text.lower() not in stop_words]

        # Preserve named entities
        entities = [ent.text for ent in doc.ents]

        processed_text = ' '.join(tokens) if tokens else keyword.lower()
        processed_keywords.append(processed_text)
    return processed_keywords

print("Preprocessing keywords...")
keywords_processed = preprocess_keywords(keywords)
df['keyword_processed'] = keywords_processed
print("✅ Keywords preprocessed.")

# SEMANTIC IMPROVEMENT 1: Use Sentence-BERT locally for better embeddings
# This provides high-quality semantic embeddings without API costs
try:
    from sentence_transformers import SentenceTransformer
    print("Using Sentence-BERT for high-quality local embeddings...")

    # Load a lightweight model that's good for keyword-style short text
    model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

    # Generate embeddings locally
    embeddings = model.encode(df['keyword_processed'].fillna(''), show_progress_bar=True)
    keyword_embeddings = embeddings
    print(f"✅ Generated {len(keyword_embeddings)} embeddings using Sentence-BERT")

    USE_SBERT = True
except ImportError:
    print("Sentence-BERT not available, falling back to OpenAI embeddings")
    USE_SBERT = False

# If Sentence-BERT is not available, use OpenAI embeddings selectively
if not USE_SBERT:
    # ✅ Generate embeddings using a cost-effective approach
    # SEMANTIC IMPROVEMENT 2: Use a representative sample strategy for large datasets
    def sample_and_embed_keywords(keywords, sample_size=1000, model="text-embedding-ada-002"):
        """Intelligently sample keywords and generate embeddings"""
        N = len(keywords)

        if N <= sample_size:
            # For small datasets, embed everything
            sample_indices = list(range(N))
            full_sample = keywords
        else:
            # For large datasets, use intelligent sampling:
            # 1. Split keywords into chunks and take representatives from each
            chunk_size = N // (sample_size // 2)
            sample_indices = []

            # Get keywords from each chunk
            for i in range(0, N, chunk_size):
                chunk = keywords[i:i+chunk_size]
                # Take ~2 keywords from each chunk
                sample_count = max(1, min(2, len(chunk) // 5))
                chunk_indices = list(range(i, min(i+chunk_size, N)))
                if chunk_indices:
                    selected = np.random.choice(chunk_indices, sample_count, replace=False)
                    sample_indices.extend(selected)

            # 2. Add some completely random keywords to ensure diversity
            remaining = sample_size - len(sample_indices)
            if remaining > 0:
                remaining_indices = list(set(range(N)) - set(sample_indices))
                if remaining_indices:
                    random_indices = np.random.choice(remaining_indices,
                                                    min(remaining, len(remaining_indices)),
                                                    replace=False)
                    sample_indices.extend(random_indices)

            full_sample = [keywords[i] for i in sample_indices]

        # Generate embeddings for the sample
        try:
            response = client.embeddings.create(
                model=model,
                input=[k for k in full_sample if k]
            )
            sample_embeddings = np.array([item.embedding for item in response.data])
            print(f"✅ Generated embeddings for {len(sample_embeddings)} sample keywords")

            return sample_embeddings, sample_indices
        except Exception as e:
            print(f"❌ Error generating embeddings: {e}")
            return None, sample_indices

    # Generate embeddings for a sample
    sample_size = min(1000, len(df))
    sample_embeddings, sample_indices = sample_and_embed_keywords(
        df['keyword_processed'].tolist(),
        sample_size=sample_size
    )

    if sample_embeddings is None:
        print("Falling back to TF-IDF vectorization...")
        vectorizer = TfidfVectorizer(max_features=300)
        tfidf_matrix = vectorizer.fit_transform(df['keyword_processed'].fillna(''))
        keyword_embeddings = tfidf_matrix.toarray()
    else:
        # SEMANTIC IMPROVEMENT 3: Propagate embeddings to similar keywords
        print("Propagating embeddings to similar keywords...")
        # Create TF-IDF matrix for all keywords
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(df['keyword_processed'].fillna(''))

        # For each non-sampled keyword, find the most similar sampled keyword and use its embedding
        keyword_embeddings = np.zeros((len(df), sample_embeddings.shape[1]))
        for i in sample_indices:
            keyword_embeddings[i] = sample_embeddings[sample_indices.index(i)]

        # For non-sampled keywords, find the most similar sampled keyword
        for i in range(len(df)):
            if i not in sample_indices:
                similarities = cosine_similarity(
                    tfidf_matrix[i:i+1],
                    tfidf_matrix[sample_indices]
                )[0]
                most_similar_idx = sample_indices[np.argmax(similarities)]
                keyword_embeddings[i] = keyword_embeddings[most_similar_idx]

        print(f"✅ Propagated embeddings to all {len(keyword_embeddings)} keywords")

# ✅ Step 4b: Apply Dimensionality Reduction (PCA)
try:
    max_components = min(50, keyword_embeddings.shape[0], keyword_embeddings.shape[1])
    pca = PCA(n_components=max_components)
    keyword_embeddings = pca.fit_transform(keyword_embeddings)
    print(f"✅ Dimensionality reduction applied (PCA) to {max_components} dimensions.")
except Exception as e:
    print(f"❌ Error with PCA: {e}")
    exit(1)

# ✅ Step 5: Clustering using Hierarchical Clustering
num_clusters = min(20, len(df))  # Ensure we don't create more clusters than data points
try:
    Z = linkage(keyword_embeddings, method="ward")
    df["cluster_id"] = fcluster(Z, t=num_clusters, criterion="maxclust")
    print(f"✅ Keywords successfully clustered into {num_clusters} groups.")
except Exception as e:
    print(f"❌ Error in clustering: {e}")
    exit(1)

# SEMANTIC IMPROVEMENT 4: Generate representative keywords for each cluster
def get_representative_keywords(df, cluster_id, n=10):
    """Get the most representative keywords for a cluster based on embedding similarity"""
    cluster_df = df[df['cluster_id'] == cluster_id]
    if len(cluster_df) <= n:
        return cluster_df['keyword'].tolist()

    # Calculate centroid of the cluster
    indices = cluster_df.index.tolist()
    cluster_embeddings = np.array([keyword_embeddings[i] for i in indices])
    centroid = np.mean(cluster_embeddings, axis=0)

    # Calculate distance to centroid for each keyword
    distances = [np.linalg.norm(emb - centroid) for emb in cluster_embeddings]

    # Get indices of keywords closest to centroid
    closest_indices = np.argsort(distances)[:n]
    representative_keywords = [cluster_df.iloc[i]['keyword'] for i in closest_indices]

    return representative_keywords

# SEMANTIC IMPROVEMENT 5: Generate better cluster names and descriptions
# with a two-step process that first understands the cluster, then names it
def generate_improved_cluster_names(clusters_with_representatives):
    """
    Two-step process for better cluster naming:
    1. First analyze each cluster's representative keywords
    2. Then generate a name and description based on that analysis
    """
    if not clusters_with_representatives:
        return {}

    results = {}

    # Process clusters in smaller batches to manage costs
    batch_size = 5
    for batch_start in range(0, len(clusters_with_representatives), batch_size):
        batch_end = min(batch_start + batch_size, len(clusters_with_representatives))
        batch_clusters = list(clusters_with_representatives.items())[batch_start:batch_end]

        try:
            # Step 1: Analyze clusters
            analysis_prompt = "I'll provide representative keywords for several clusters. For each cluster, analyze the keywords to identify common themes, topics, or categories.\n\n"

            for cluster_id, keywords in batch_clusters:
                analysis_prompt += f"Cluster {cluster_id} representative keywords: {', '.join(keywords[:15])}\n\n"

            analysis_response = client.chat.completions.create(
                model="gpt-3.5-turbo",  # Use cheaper model for analysis
                messages=[{"role": "user", "content": analysis_prompt}],
                temperature=0.1,
                max_tokens=300
            )

            analysis_text = analysis_response.choices[0].message.content.strip()

            # Step 2: Generate names and descriptions based on analysis
            naming_prompt = f"""Based on the following analysis of keyword clusters, provide a specific name and description for each cluster.

Analysis:
{analysis_text}

For each cluster, provide:
1. A short, specific cluster name (3-5 words)
2. A one-sentence description that accurately represents the theme

Respond in JSON format:
{{
  "clusters": [
    {{
      "cluster_id": 1,
      "cluster_name": "...",
      "description": "..."
    }},
    ...
  ]
}}
"""

            naming_response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[{"role": "user", "content": naming_prompt}],
                temperature=0.2,
                max_tokens=200,
                response_format={"type": "json_object"}
            )

            naming_text = naming_response.choices[0].message.content.strip()
            data = json.loads(naming_text)

            # Extract results
            for cluster_info in data.get("clusters", []):
                cluster_id_str = str(cluster_info.get("cluster_id"))
                # Match string cluster ID to our numeric cluster IDs
                for actual_id, _ in batch_clusters:
                    if str(actual_id) == cluster_id_str:
                        results[actual_id] = (
                            cluster_info.get("cluster_name", f"Cluster {actual_id}"),
                            cluster_info.get("description", "No description provided.")
                        )

            # Fill in any missing clusters from this batch
            for cluster_id, _ in batch_clusters:
                if cluster_id not in results:
                    results[cluster_id] = (f"Cluster {cluster_id}", "No description generated")

            print(f"Processed cluster name batch {batch_start//batch_size + 1}")
            time.sleep(1)

        except Exception as e:
            print(f"Error generating names for batch starting at {batch_start}: {e}")
            # Provide default names for all clusters in this batch
            for cluster_id, _ in batch_clusters:
                results[cluster_id] = (f"Cluster {cluster_id}", "Error generating description")

    return results

# Get representative keywords for each cluster
print("Identifying representative keywords for each cluster...")
clusters_with_representatives = {}
for cluster_num in df['cluster_id'].unique():
    representatives = get_representative_keywords(df, cluster_num, n=15)
    clusters_with_representatives[cluster_num] = representatives
    print(f"Cluster {cluster_num}: Found {len(representatives)} representative keywords")

# Generate improved cluster names
print("Generating semantically improved cluster names and descriptions...")
cluster_names = generate_improved_cluster_names(clusters_with_representatives)

# Apply results to dataframe
df['cluster_name'] = ''
df['cluster_description'] = ''
df['representative'] = False

for cluster_num, (name, description) in cluster_names.items():
    df.loc[df['cluster_id'] == cluster_num, 'cluster_name'] = name
    df.loc[df['cluster_id'] == cluster_num, 'cluster_description'] = description

    # Mark representative keywords
    for keyword in clusters_with_representatives.get(cluster_num, []):
        matching_indices = df[(df['cluster_id'] == cluster_num) & (df['keyword'] == keyword)].index
        if not matching_indices.empty:
            df.loc[matching_indices, 'representative'] = True

    print(f"Cluster {cluster_num}: {name} - {description}")

# SEMANTIC IMPROVEMENT 6: Calculate semantic coherence scores for each cluster
def calculate_cluster_coherence(cluster_embeddings):
    """Calculate semantic coherence of a cluster based on embedding similarity"""
    if len(cluster_embeddings) <= 1:
        return 1.0  # Perfect coherence for single element

    # Calculate centroid
    centroid = np.mean(cluster_embeddings, axis=0)

    # Calculate average cosine similarity to centroid
    similarities = []
    for emb in cluster_embeddings:
        similarity = np.dot(emb, centroid) / (np.linalg.norm(emb) * np.linalg.norm(centroid))
        similarities.append(similarity)

    return np.mean(similarities)

# Calculate coherence for each cluster
print("Calculating semantic coherence for each cluster...")
df['cluster_coherence'] = 0.0

for cluster_num in df['cluster_id'].unique():
    cluster_indices = df[df['cluster_id'] == cluster_num].index.tolist()
    cluster_embeddings = np.array([keyword_embeddings[i] for i in cluster_indices])
    coherence = calculate_cluster_coherence(cluster_embeddings)
    df.loc[df['cluster_id'] == cluster_num, 'cluster_coherence'] = coherence
    print(f"Cluster {cluster_num}: Coherence = {coherence:.3f}")

# ✅ Step 7: Save the Results
try:
    output_file = "semantic_clustered_keywords.csv"
    df.to_csv(output_file, index=False)
    print(f"✅ Semantic clustering complete! Results saved to '{output_file}'.")

    # Print summary
    print("\nClustering Summary:")
    for cluster_num in df['cluster_id'].unique():
        count = len(df[df['cluster_id'] == cluster_num])
        name = df[df['cluster_id'] == cluster_num]['cluster_name'].iloc[0]
        coherence = df[df['cluster_id'] == cluster_num]['cluster_coherence'].iloc[0]
        print(f"Cluster {cluster_num}: {name} - {count} keywords (Coherence: {coherence:.3f})")

        # Print some representative examples
        print("  Representative keywords:")
        representatives = df[(df['cluster_id'] == cluster_num) & (df['representative'] == True)]['keyword'].tolist()[:5]
        for rep in representatives:
            print(f"    - {rep}")
except Exception as e:
    print(f"❌ Error saving results: {e}")
# Out:
# Enter your OpenAI API key: ··········
# ✅ Loaded 1871 keywords from keywords.csv
# Preprocessing keywords...
# ✅ Keywords preprocessed.
# Using Sentence-BERT for high-quality local embeddings...
# Batches:   0%|          | 0/59 [00:00<?, ?it/s]
# ✅ Generated 1871 embeddings using Sentence-BERT
# ✅ Dimensionality reduction applied (PCA) to 50 dimensions.
# ✅ Keywords successfully clustered into 20 groups.
# Identifying representative keywords for each cluster...
# Cluster 13: Found 15 representative keywords
# Cluster 2: Found 15 representative keywords
# Cluster 4: Found 15 representative keywords
# Cluster 15: Found 15 representative keywords
# Cluster 1: Found 15 representative keywords
# Cluster 12: Found 15 representative keywords
# Cluster 17: Found 15 representative keywords
# Cluster 20: Found 15 representative keywords
# Cluster 18: Found 15 representative keywords
# Cluster 16: Found 15 representative keywords
# Cluster 11: Found 15 representative keywords
# Cluster 19: Found 15 representative keywords
# Cluster 10: Found 15 representative keywords
# Cluster 14: Found 15 representative keywords
# Cluster 3: Found 15 representative keywords
# Cluster 7: Found 15 representative keywords
# Cluster 5: Found 15 representative keywords
# Cluster 9: Found 15 representative keywords
# Cluster 6: Found 15 representative keywords
# Cluster 8: Found 14 representative keywords
# Generating semantically improved cluster names and descriptions...
# Error generating names for batch starting at 0: Unterminated string starting at: line 26 column 22 (char 830)
# Error generating names for batch starting at 5: Unterminated string starting at: line 25 column 23 (char 830)
# Error generating names for batch starting at 10: Unterminated string starting at: line 25 column 23 (char 787)
# Error generating names for batch starting at 15: Expecting property name enclosed in double quotes: line 24 column 23 (char 820)
# Cluster 13: Cluster 13 - Error generating description
# Cluster 2: Cluster 2 - Error generating description
# Cluster 4: Cluster 4 - Error generating description
# Cluster 15: Cluster 15 - Error generating description
# Cluster 1: Cluster 1 - Error generating description
# Cluster 12: Cluster 12 - Error generating description
# Cluster 17: Cluster 17 - Error generating description
# Cluster 20: Cluster 20 - Error generating description
# Cluster 18: Cluster 18 - Error generating description
# Cluster 16: Cluster 16 - Error generating description
# Cluster 11: Cluster 11 - Error generating description
# Cluster 19: Cluster 19 - Error generating description
# Cluster 10: Cluster 10 - Error generating description
# Cluster 14: Cluster 14 - Error generating description
# Cluster 3: Cluster 3 - Error generating description
# Cluster 7: Cluster 7 - Error generating description
# Cluster 5: Cluster 5 - Error generating description
# Cluster 9: Cluster 9 - Error generating description
# Cluster 6: Cluster 6 - Error generating description
# Cluster 8: Cluster 8 - Error generating description
# Calculating semantic coherence for each cluster...
# Cluster 13: Coherence = 0.430
# Cluster 2: Coherence = 0.709
# Cluster 4: Coherence = 0.579
# Cluster 15: Coherence = 0.782
# Cluster 1: Coherence = 0.860
# Cluster 12: Coherence = 0.396
# Cluster 17: Coherence = 0.902
# Cluster 20: Coherence = 0.511
# Cluster 18: Coherence = 0.869
# Cluster 16: Coherence = 0.741
# Cluster 11: Coherence = 0.331
# Cluster 19: Coherence = 0.797
# Cluster 10: Coherence = 0.834
# Cluster 14: Coherence = 0.465
# Cluster 3: Coherence = 0.838
# Cluster 7: Coherence = 0.721
# Cluster 5: Coherence = 0.871
# Cluster 9: Coherence = 0.656
# Cluster 6: Coherence = 0.875
# Cluster 8: Coherence = 0.933
# ✅ Semantic clustering complete! Results saved to 'semantic_clustered_keywords.csv'.
#
# Clustering Summary:
# Cluster 13: Cluster 13 - 279 keywords (Coherence: 0.430)
#   Representative keywords:
#     - moma
#     - moma newera
#     - must see in moma
#     - moma 2023
#     - moma post
# Cluster 2: Cluster 2 - 132 keywords (Coherence: 0.709)
#   Representative keywords:
#     - the moma museum
#     - moma museum
#     - moma the museum
#     - moma ps1 museum
#     - moma exhibitions 2023
# Cluster 4: Cluster 4 - 175 keywords (Coherence: 0.579)
#   Representative keywords:
#     - art at the moma
#     - moma art
#     - moma artworks
#     - moma famous artwork
#     - moma paintings
# Cluster 15: Cluster 15 - 100 keywords (Coherence: 0.782)
#   Representative keywords:
#     - moma store
#     - moma store shop
#     - shop moma store
#     - store moma
#     - the moma store
# Cluster 1: Cluster 1 - 73 keywords (Coherence: 0.860)
#   Representative keywords:
#     - museum of modern art design
#     - the museum of modern art nyc
#     - museum of modern art collection
#     - history of museum of modern art
#     - museum of modern art reviews
# Cluster 12: Cluster 12 - 101 keywords (Coherence: 0.396)
#   Representative keywords:
#     - meret oppenheim moma
#     - moma mies van der rohe
#     - mies van der rohe moma
#     - moma tillmans
#     - florine stettheimer moma
# Cluster 17: Cluster 17 - 57 keywords (Coherence: 0.902)
#   Representative keywords:
#     - moma tickets
#     - cheap moma tickets
#     - moma ps1 tickets
#     - moma student tickets
#     - buy tickets moma
# Cluster 20: Cluster 20 - 127 keywords (Coherence: 0.511)
#   Representative keywords:
#     - first friday moma
#     - visit moma
#     - visit the moma
#     - moma friday night
#     - best time to visit moma
# Cluster 18: Cluster 18 - 55 keywords (Coherence: 0.869)
#   Representative keywords:
#     - moma hours
#     - moma's hours
#     - moma hours today
#     - moma hours on sunday
#     - moma hours on saturday
# Cluster 16: Cluster 16 - 73 keywords (Coherence: 0.741)
#   Representative keywords:
#     - moma restaurant
#     - best restaurant near moma
#     - restaurant near moma
#     - the modern restaurant moma
#     - places to eat near moma
# Cluster 11: Cluster 11 - 94 keywords (Coherence: 0.331)
#   Representative keywords:
#     - matisse red studio moma
#     - matisse the red studio moma
#     - red studio matisse moma
#     - bjork moma exhibition
#     - international style moma
# Cluster 19: Cluster 19 - 32 keywords (Coherence: 0.797)
#   Representative keywords:
#     - free moma admission
#     - free moma entry
#     - moma free admission
#     - moma admission
#     - moma free entry
# Cluster 10: Cluster 10 - 27 keywords (Coherence: 0.834)
#   Representative keywords:
#     - moma and uniqlo
#     - moma uniqlo
#     - uniqlo and moma
#     - uniqlo moma
#     - moma uniqlo night
# Cluster 14: Cluster 14 - 375 keywords (Coherence: 0.465)
#   Representative keywords:
#     - vangogh moma
#     - kathe kollwitz moma
#     - joan miro moma
#     - eames moma
#     - malevich moma
# Cluster 3: Cluster 3 - 35 keywords (Coherence: 0.838)
#   Representative keywords:
#     - moma van gogh
#     - van gogh at the moma
#     - moma picasso paintings
#     - moma vincent van gogh
#     - picasso moma paintings
# Cluster 7: Cluster 7 - 37 keywords (Coherence: 0.721)
#   Representative keywords:
#     - andy warhol moma
#     - moma andy warhol
#     - moma warhol
#     - warhol at the moma
#     - warhol in moma
# Cluster 5: Cluster 5 - 26 keywords (Coherence: 0.871)
#   Representative keywords:
#     - lego moma
#     - moma lego
#     - moma legos
#     - moma lego set
#     - moma lego sets
# Cluster 9: Cluster 9 - 38 keywords (Coherence: 0.656)
#   Representative keywords:
#     - monet lilies moma
#     - monet moma water lilies
#     - monet water lilies moma
#     - moma monet
#     - monet in moma
# Cluster 6: Cluster 6 - 21 keywords (Coherence: 0.875)
#   Representative keywords:
#     - moma yankee hat
#     - yankees moma hat
#     - moma ny cap
#     - moma yankees cap
#     - ny moma hat
# Cluster 8: Cluster 8 - 14 keywords (Coherence: 0.933)
#   Representative keywords:
#     - moma pinocchio
#     - museum of modern art pinocchio
#     - pinocchio moma
#     - pinocchio museum of modern art
#     - pinocchio exhibit moma

# %%
import os
import time
import json
import numpy as np
import pandas as pd
from getpass import getpass
from openai import OpenAI
import nltk
import spacy
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics.pairwise import cosine_similarity

# Install dependencies (uncomment if needed)
# !pip install openai pandas numpy scikit-learn nltk spacy tqdm sentence-transformers
# !python -m spacy download en_core_web_sm

# Download NLTK resources
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

# Load SpaCy model
try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    print("Downloading SpaCy model...")
    os.system("python -m spacy download en_core_web_sm")
    nlp = spacy.load("en_core_web_sm")

# ✅ Step 1: Set up API Key securely
os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")
client = OpenAI()

# ✅ Step 2: Load and Preprocess Dataset
CSV_FILE = "keywords.csv"
try:
    df = pd.read_csv(CSV_FILE, header=None, names=["keyword"])
    keywords = df["keyword"].tolist()
    print(f"✅ Loaded {len(keywords)} keywords from {CSV_FILE}")
except FileNotFoundError:
    print(f"❌ File not found: {CSV_FILE}")
    exit(1)

# Preprocess keywords
stop_words = set(stopwords.words('french')).union(stopwords.words('english'))

def preprocess_keywords(keywords):
    processed_keywords = []
    for keyword in keywords:
        if not isinstance(keyword, str):
            processed_keywords.append("")
            continue

        doc = nlp(keyword.lower())  # Process keyword with SpaCy
        tokens = [token.text for token in doc if token.is_alpha and token.text.lower() not in stop_words]

        # Preserve named entities
        entities = [ent.text for ent in doc.ents]

        processed_text = ' '.join(tokens) if tokens else keyword.lower()
        processed_keywords.append(processed_text)
    return processed_keywords

print("Preprocessing keywords...")
keywords_processed = preprocess_keywords(keywords)
df['keyword_processed'] = keywords_processed
print("✅ Keywords preprocessed.")

# SEMANTIC IMPROVEMENT 1: Use Sentence-BERT locally for better embeddings
# This provides high-quality semantic embeddings without API costs
try:
    from sentence_transformers import SentenceTransformer
    print("Using Sentence-BERT for high-quality local embeddings...")

    # Load a lightweight model that's good for keyword-style short text
    model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

    # Generate embeddings locally
    embeddings = model.encode(df['keyword_processed'].fillna(''), show_progress_bar=True)
    keyword_embeddings = embeddings
    print(f"✅ Generated {len(keyword_embeddings)} embeddings using Sentence-BERT")

    USE_SBERT = True
except ImportError:
    print("Sentence-BERT not available, falling back to OpenAI embeddings")
    USE_SBERT = False

# If Sentence-BERT is not available, use OpenAI embeddings selectively
if not USE_SBERT:
    # ✅ Generate embeddings using a cost-effective approach
    # SEMANTIC IMPROVEMENT 2: Use a representative sample strategy for large datasets
    def sample_and_embed_keywords(keywords, sample_size=1000, model="text-embedding-ada-002"):
        """Intelligently sample keywords and generate embeddings"""
        N = len(keywords)

        if N <= sample_size:
            # For small datasets, embed everything
            sample_indices = list(range(N))
            full_sample = keywords
        else:
            # For large datasets, use intelligent sampling:
            # 1. Split keywords into chunks and take representatives from each
            chunk_size = N // (sample_size // 2)
            sample_indices = []

            # Get keywords from each chunk
            for i in range(0, N, chunk_size):
                chunk = keywords[i:i+chunk_size]
                # Take ~2 keywords from each chunk
                sample_count = max(1, min(2, len(chunk) // 5))
                chunk_indices = list(range(i, min(i+chunk_size, N)))
                if chunk_indices:
                    selected = np.random.choice(chunk_indices, sample_count, replace=False)
                    sample_indices.extend(selected)

            # 2. Add some completely random keywords to ensure diversity
            remaining = sample_size - len(sample_indices)
            if remaining > 0:
                remaining_indices = list(set(range(N)) - set(sample_indices))
                if remaining_indices:
                    random_indices = np.random.choice(remaining_indices,
                                                    min(remaining, len(remaining_indices)),
                                                    replace=False)
                    sample_indices.extend(random_indices)

            full_sample = [keywords[i] for i in sample_indices]

        # Generate embeddings for the sample
        try:
            response = client.embeddings.create(
                model=model,
                input=[k for k in full_sample if k]
            )
            sample_embeddings = np.array([item.embedding for item in response.data])
            print(f"✅ Generated embeddings for {len(sample_embeddings)} sample keywords")

            return sample_embeddings, sample_indices
        except Exception as e:
            print(f"❌ Error generating embeddings: {e}")
            return None, sample_indices

    # Generate embeddings for a sample
    sample_size = min(1000, len(df))
    sample_embeddings, sample_indices = sample_and_embed_keywords(
        df['keyword_processed'].tolist(),
        sample_size=sample_size
    )

    if sample_embeddings is None:
        print("Falling back to TF-IDF vectorization...")
        vectorizer = TfidfVectorizer(max_features=300)
        tfidf_matrix = vectorizer.fit_transform(df['keyword_processed'].fillna(''))
        keyword_embeddings = tfidf_matrix.toarray()
    else:
        # SEMANTIC IMPROVEMENT 3: Propagate embeddings to similar keywords
        print("Propagating embeddings to similar keywords...")
        # Create TF-IDF matrix for all keywords
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(df['keyword_processed'].fillna(''))

        # For each non-sampled keyword, find the most similar sampled keyword and use its embedding
        keyword_embeddings = np.zeros((len(df), sample_embeddings.shape[1]))
        for i in sample_indices:
            keyword_embeddings[i] = sample_embeddings[sample_indices.index(i)]

        # For non-sampled keywords, find the most similar sampled keyword
        for i in range(len(df)):
            if i not in sample_indices:
                similarities = cosine_similarity(
                    tfidf_matrix[i:i+1],
                    tfidf_matrix[sample_indices]
                )[0]
                most_similar_idx = sample_indices[np.argmax(similarities)]
                keyword_embeddings[i] = keyword_embeddings[most_similar_idx]

        print(f"✅ Propagated embeddings to all {len(keyword_embeddings)} keywords")

# ✅ Step 4b: Apply Dimensionality Reduction (PCA)
try:
    # Determine optimal number of components experimentally
    pca = PCA()
    pca.fit(keyword_embeddings)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    # Find the number of components that explain 90% of variance
    n_components = np.argmax(cumulative_variance >= 0.90) + 1
    print(f"Number of components for 90% variance: {n_components}")
    # Use that number (with a reasonable cap)
    max_components = min(n_components, 75)
    pca = PCA(n_components=max_components)
    keyword_embeddings = pca.fit_transform(keyword_embeddings)
    print(f"✅ Dimensionality reduction applied (PCA) to {max_components} dimensions (90% variance explained).")
except Exception as e:
    print(f"❌ Error with PCA: {e}")
    exit(1)

# ✅ Step 5: Clustering using Hierarchical Clustering
num_clusters = min(30, len(df))  # Ensure we don't create more clusters than data points
try:
    Z = linkage(keyword_embeddings, method="ward")
    df["cluster_id"] = fcluster(Z, t=num_clusters, criterion="maxclust")
    print(f"✅ Keywords successfully clustered into {num_clusters} groups.")
except Exception as e:
    print(f"❌ Error in clustering: {e}")
    exit(1)

# SEMANTIC IMPROVEMENT 4: Generate representative keywords for each cluster
def get_representative_keywords(df, cluster_id, n=10):
    """Get the most representative keywords for a cluster based on embedding similarity"""
    cluster_df = df[df['cluster_id'] == cluster_id]
    if len(cluster_df) <= n:
        return cluster_df['keyword'].tolist()

    # Calculate centroid of the cluster
    indices = cluster_df.index.tolist()
    cluster_embeddings = np.array([keyword_embeddings[i] for i in indices])
    centroid = np.mean(cluster_embeddings, axis=0)

    # Calculate distance to centroid for each keyword
    distances = [np.linalg.norm(emb - centroid) for emb in cluster_embeddings]

    # Get indices of keywords closest to centroid
    closest_indices = np.argsort(distances)[:n]
    representative_keywords = [cluster_df.iloc[i]['keyword'] for i in closest_indices]

    return representative_keywords

# SEMANTIC IMPROVEMENT 5: Generate better cluster names and descriptions
# with a two-step process that first understands the cluster, then names it
def generate_improved_cluster_names(clusters_with_representatives):
    """
    Two-step process for better cluster naming:
    1. First analyze each cluster's representative keywords
    2. Then generate a name and description based on that analysis
    """
    if not clusters_with_representatives:
        return {}

    results = {}

    # Process clusters in smaller batches to manage costs
    batch_size = 5
    for batch_start in range(0, len(clusters_with_representatives), batch_size):
        batch_end = min(batch_start + batch_size, len(clusters_with_representatives))
        batch_clusters = list(clusters_with_representatives.items())[batch_start:batch_end]

        try:
            # Step 1: Analyze clusters
            analysis_prompt = "I'll provide representative keywords for several clusters. For each cluster, analyze the keywords to identify common themes, topics, or categories.\n\n"

            # Track the cluster order to match the response
            cluster_order = []
            for cluster_id, keywords in batch_clusters:
                cluster_order.append(cluster_id)
                analysis_prompt += f"Cluster {cluster_id} representative keywords: {', '.join(keywords[:15])}\n\n"

            analysis_response = client.chat.completions.create(
                model="gpt-3.5-turbo",  # Use cheaper model for analysis
                messages=[{"role": "user", "content": analysis_prompt}],
                temperature=0.1,
                max_tokens=300
            )

            analysis_text = analysis_response.choices[0].message.content.strip()

            # Step 2: Generate names and descriptions based on analysis
            naming_prompt = f"""Based on the following analysis of keyword clusters, provide a specific name and description for each cluster.

Analysis:
{analysis_text}

For each cluster, provide:
1. A short, specific cluster name (3-5 words)
2. A one-sentence description that accurately represents the theme

Format your response as a JSON array, with each element containing cluster_id, cluster_name, and description for clusters {', '.join(map(str, cluster_order))}.
"""

            naming_response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[{"role": "user", "content": naming_prompt}],
                temperature=0.2,
                max_tokens=400,
                response_format={"type": "json_object"}
            )

            naming_text = naming_response.choices[0].message.content.strip()
            print(f"DEBUG: Raw JSON response: {naming_text}")

            try:
                data = json.loads(naming_text)

                # Handle different JSON structures that might be returned
                clusters_data = None
                if "clusters" in data:
                    clusters_data = data["clusters"]
                elif isinstance(data, list):
                    clusters_data = data
                else:
                    # Try to find any list in the response
                    for key, value in data.items():
                        if isinstance(value, list) and len(value) > 0:
                            clusters_data = value
                            break

                if not clusters_data:
                    raise ValueError("Could not find clusters data in JSON response")

                # Match clusters by position if IDs don't match
                if len(clusters_data) == len(cluster_order):
                    for i, cluster_info in enumerate(clusters_data):
                        actual_id = cluster_order[i]
                        results[actual_id] = (
                            cluster_info.get("cluster_name", f"Cluster {actual_id}"),
                            cluster_info.get("description", "No description provided.")
                        )
                else:
                    # Try matching by ID if available
                    for cluster_info in clusters_data:
                        if "cluster_id" in cluster_info:
                            # Try to match cluster IDs flexibly
                            cluster_id_str = str(cluster_info["cluster_id"]).strip()
                            for actual_id in cluster_order:
                                if str(actual_id) == cluster_id_str:
                                    results[actual_id] = (
                                        cluster_info.get("cluster_name", f"Cluster {actual_id}"),
                                        cluster_info.get("description", "No description provided.")
                                    )

            except json.JSONDecodeError as e:
                print(f"Error parsing JSON response: {e}")
                print(f"Response was: {naming_text}")
                # Handle the error gracefully - assign default names
                for i, cluster_id in enumerate(cluster_order):
                    results[cluster_id] = (f"Cluster {cluster_id}", "Error parsing JSON response")

            # Fill in any missing clusters from this batch
            for cluster_id, _ in batch_clusters:
                if cluster_id not in results:
                    results[cluster_id] = (f"Cluster {cluster_id}", "No description generated")

            print(f"Processed cluster name batch {batch_start//batch_size + 1}")
            time.sleep(1)

        except Exception as e:
            print(f"Error generating names for batch starting at {batch_start}: {e}")
            # Provide default names for all clusters in this batch
            for cluster_id, _ in batch_clusters:
                results[cluster_id] = (f"Cluster {cluster_id}", "Error generating description")

    return results

# Get representative keywords for each cluster
print("Identifying representative keywords for each cluster...")
clusters_with_representatives = {}
for cluster_num in df['cluster_id'].unique():
    representatives = get_representative_keywords(df, cluster_num, n=15)
    clusters_with_representatives[cluster_num] = representatives
    print(f"Cluster {cluster_num}: Found {len(representatives)} representative keywords")

# Generate improved cluster names
print("Generating semantically improved cluster names and descriptions...")
cluster_names = generate_improved_cluster_names(clusters_with_representatives)

# Apply results to dataframe
df['cluster_name'] = ''
df['cluster_description'] = ''
df['representative'] = False

for cluster_num, (name, description) in cluster_names.items():
    df.loc[df['cluster_id'] == cluster_num, 'cluster_name'] = name
    df.loc[df['cluster_id'] == cluster_num, 'cluster_description'] = description

    # Mark representative keywords
    for keyword in clusters_with_representatives.get(cluster_num, []):
        matching_indices = df[(df['cluster_id'] == cluster_num) & (df['keyword'] == keyword)].index
        if not matching_indices.empty:
            df.loc[matching_indices, 'representative'] = True

    print(f"Cluster {cluster_num}: {name} - {description}")

# SEMANTIC IMPROVEMENT 6: Calculate semantic coherence scores for each cluster
def calculate_cluster_coherence(cluster_embeddings):
    """Calculate semantic coherence of a cluster based on embedding similarity"""
    if len(cluster_embeddings) <= 1:
        return 1.0  # Perfect coherence for single element

    # Calculate centroid
    centroid = np.mean(cluster_embeddings, axis=0)

    # Calculate average cosine similarity to centroid
    similarities = []
    for emb in cluster_embeddings:
        similarity = np.dot(emb, centroid) / (np.linalg.norm(emb) * np.linalg.norm(centroid))
        similarities.append(similarity)

    return np.mean(similarities)

# Calculate coherence for each cluster
print("Calculating semantic coherence for each cluster...")
df['cluster_coherence'] = 0.0

for cluster_num in df['cluster_id'].unique():
    cluster_indices = df[df['cluster_id'] == cluster_num].index.tolist()
    cluster_embeddings = np.array([keyword_embeddings[i] for i in cluster_indices])
    coherence = calculate_cluster_coherence(cluster_embeddings)
    df.loc[df['cluster_id'] == cluster_num, 'cluster_coherence'] = coherence
    print(f"Cluster {cluster_num}: Coherence = {coherence:.3f}")

# ✅ Step 7: Save the Results
try:
    output_file = "semantic_clustered_keywords.csv"
    df.to_csv(output_file, index=False)
    print(f"✅ Semantic clustering complete! Results saved to '{output_file}'.")

    # Print summary
    print("\nClustering Summary:")
    for cluster_num in df['cluster_id'].unique():
        count = len(df[df['cluster_id'] == cluster_num])
        name = df[df['cluster_id'] == cluster_num]['cluster_name'].iloc[0]
        coherence = df[df['cluster_id'] == cluster_num]['cluster_coherence'].iloc[0]
        print(f"Cluster {cluster_num}: {name} - {count} keywords (Coherence: {coherence:.3f})")

        # Print some representative examples
        print("  Representative keywords:")
        representatives = df[(df['cluster_id'] == cluster_num) & (df['representative'] == True)]['keyword'].tolist()[:5]
        for rep in representatives:
            print(f"    - {rep}")
except Exception as e:
    print(f"❌ Error saving results: {e}")
# Out:
# Enter your OpenAI API key: ··········
# ✅ Loaded 12916 keywords from keywords.csv
# Preprocessing keywords...
# ✅ Keywords preprocessed.
# Using Sentence-BERT for high-quality local embeddings...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.51k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/404 [00:00<?, ?it/s]
# ✅ Generated 12916 embeddings using Sentence-BERT
# Number of components for 90% variance: 81
# ✅ Dimensionality reduction applied (PCA) to 75 dimensions (90% variance explained).
# ✅ Keywords successfully clustered into 30 groups.
# Identifying representative keywords for each cluster...
# Cluster 27: Found 15 representative keywords
# Cluster 1: Found 15 representative keywords
# Cluster 19: Found 15 representative keywords
# Cluster 30: Found 15 representative keywords
# Cluster 3: Found 15 representative keywords
# Cluster 21: Found 15 representative keywords
# Cluster 2: Found 15 representative keywords
# Cluster 22: Found 15 representative keywords
# Cluster 10: Found 15 representative keywords
# Cluster 5: Found 15 representative keywords
# Cluster 4: Found 15 representative keywords
# Cluster 28: Found 15 representative keywords
# Cluster 8: Found 15 representative keywords
# Cluster 25: Found 15 representative keywords
# Cluster 23: Found 15 representative keywords
# Cluster 20: Found 15 representative keywords
# Cluster 24: Found 15 representative keywords
# Cluster 18: Found 15 representative keywords
# Cluster 11: Found 15 representative keywords
# Cluster 12: Found 15 representative keywords
# Cluster 29: Found 15 representative keywords
# Cluster 16: Found 15 representative keywords
# Cluster 17: Found 15 representative keywords
# Cluster 13: Found 15 representative keywords
# Cluster 14: Found 15 representative keywords
# Cluster 9: Found 15 representative keywords
# Cluster 6: Found 15 representative keywords
# Cluster 15: Found 15 representative keywords
# Cluster 26: Found 15 representative keywords
# Cluster 7: Found 15 representative keywords
# Generating semantically improved cluster names and descriptions...
# DEBUG: Raw JSON response: {
#     "clusters": [
#         {
#             "cluster_id": 27,
#             "cluster_name": "Religious Candlelight Concerts",
#             "description": "Events and concerts featuring candlelight, orchestras, and religious themes in various locations."
#         },
#         {
#             "cluster_id": 1,
#             "cluster_name": "Candlelight Concert Reviews",
#             "description": "Reviews and information about candlelight concerts in different locations and venues."
#         },
#         {
#             "cluster_id": 19,
#             "cluster_name": "Candle Events in Various Locations",
#             "description": "Concerts and events involving candles in locations like Antwerp, Yvelines, and Besancon."
#         },
#         {
#             "cluster_id": 30,
#             "cluster_name": "Spectacles in Multiple Cities",
#             "description": "Spectacles and events in Lyon, Marseille, Toulouse, and other cities with specific dates."
#         },
#         {
#             "cluster_id": 3,
#             "cluster_name": "Diverse Candlelight Concerts",
#             "description": "Various candlelight events and concerts in different locations with specific performers."
#         }
#     ]
# }
# Processed cluster name batch 1
# DEBUG: Raw JSON response: {
#   "clusters": [
#     {
#       "cluster_id": 21,
#       "cluster_name": "Classical Candlelight Concerts",
#       "description": "Classical music concerts in various cities featuring candlelight settings."
#     },
#     {
#       "cluster_id": 2,
#       "cluster_name": "City Candlelight Events",
#       "description": "Candlelight events in different cities for various years."
#     },
#     {
#       "cluster_id": 22,
#       "cluster_name": "Fever Candlelight",
#       "description": "Keywords related to a website or event called 'Fever' with mentions of candlelight."
#     },
#     {
#       "cluster_id": 10,
#       "cluster_name": "Tribute Candlelight Events",
#       "description": "Candlelight events paying tribute to various musicians at different venues and dates."
#     },
#     {
#       "cluster_id": 5,
#       "cluster_name": "Candlelight Experiences",
#       "description": "Keywords related to candlelight experiences, photos, and events."
#     }
#   ]
# }
# Processed cluster name batch 2
# DEBUG: Raw JSON response: {
#     "clusters": [
#         {
#             "cluster_id": 4,
#             "cluster_name": "Candlelight Events",
#             "description": "Events and experiences centered around candlelight ambiance."
#         },
#         {
#             "cluster_id": 28,
#             "cluster_name": "Evening Activities in Paris",
#             "description": "Activities and events to enjoy in Paris during the evening."
#         },
#         {
#             "cluster_id": 8,
#             "cluster_name": "Candlelight Concerts in Cities",
#             "description": "Concerts featuring candlelight ambiance held in various cities."
#         },
#         {
#             "cluster_id": 25,
#             "cluster_name": "Hans Zimmer Candlelight Events",
#             "description": "Events related to Hans Zimmer, potentially candlelight concerts."
#         },
#         {
#             "cluster_id": 23,
#             "cluster_name": "Fever Candlelight Events",
#             "description": "Candlelight events organized by Fever."
#         }
#     ]
# }
# Processed cluster name batch 3
# DEBUG: Raw JSON response: {
#     "clusters": [
#         {
#             "cluster_id": 20,
#             "cluster_name": "Christmas Concerts in France",
#             "description": "Upcoming Christmas concerts in Paris, Avignon, Strasbourg, and Toulouse."
#         },
#         {
#             "cluster_id": 24,
#             "cluster_name": "Candlelight Events Worldwide",
#             "description": "Candlelight events happening in Fourviere, Brest, Como, Alicante, and London."
#         },
#         {
#             "cluster_id": 18,
#             "cluster_name": "Montreal & Paris Concerts",
#             "description": "Concerts in Montreal and Paris, including Christmas concerts and Candlelight events at the Eiffel Tower."
#         },
#         {
#             "cluster_id": 11,
#             "cluster_name": "Misspelled Candlelight Keywords",
#             "description": "Keywords related to 'candlelight' with common misspellings."
#         },
#         {
#             "cluster_id": 12,
#             "cluster_name": "Candlelight Concerts with Coldplay",
#             "description": "Candlelight concerts featuring Coldplay and Imagine Dragons in Paris, Bordeaux, Nantes, and Lyon."
#         }
#     ]
# }
# Processed cluster name batch 4
# DEBUG: Raw JSON response: {
#     "clusters": [
#         {
#             "cluster_id": 29,
#             "cluster_name": "Valentine's Day Events 2024-2025",
#             "description": "Upcoming Valentine's Day events in Strasbourg, Paris, Brest, Limoges for the years 2024 and 2025."
#         },
#         {
#             "cluster_id": 16,
#             "cluster_name": "Paris Live Music Bars",
#             "description": "Bars and clubs in Paris with live music performances, including classical and various music genres."
#         },
#         {
#             "cluster_id": 17,
#             "cluster_name": "Piano Concerts in Multiple Cities",
#             "description": "Concerts featuring piano performances in Avignon, Paris, Toulouse, Nantes, Grenoble, Strasbourg, Lille, Saint Etienne, Brussels, with some events involving candles."
#         },
#         {
#             "cluster_id": 13,
#             "cluster_name": "Halloween Events 2024",
#             "description": "Halloween events in Brest, Nantes, Luxembourg, Bordeaux, Copenhagen for the year 2024, including themed drawings and parties."
#         },
#         {
#             "cluster_id": 14,
#             "cluster_name": "Coldplay Candlelight Tributes",
#             "description": "Candlelight tribute events featuring music by Coldplay in Brest, Salerno, Evian for the years 2024 and 2025."
#         }
#     ]
# }
# Processed cluster name batch 5
# DEBUG: Raw JSON response: {
#     "clusters": [
#         {
#             "cluster_id": 9,
#             "cluster_name": "Classical Candlelight Music Events",
#             "description": "Events featuring classical music performed by candlelight."
#         },
#         {
#             "cluster_id": 6,
#             "cluster_name": "Bridgerton Candlelight Events",
#             "description": "Candlelight events inspired by the TV show Bridgerton."
#         },
#         {
#             "cluster_id": 15,
#             "cluster_name": "Coldplay Concerts in Lyon 2024",
#             "description": "Upcoming Coldplay concerts scheduled in Lyon for 2024."
#         },
#         {
#             "cluster_id": 26,
#             "cluster_name": "Spanish Candlelight Concerts",
#             "description": "Candlelight concerts taking place in various cities in Spain."
#         },
#         {
#             "cluster_id": 7,
#             "cluster_name": "Hans Zimmer Candlelight Events",
#             "description": "Candlelight events featuring music by composer Hans Zimmer."
#         }
#     ]
# }
# Processed cluster name batch 6
# Cluster 27: Religious Candlelight Concerts - Events and concerts featuring candlelight, orchestras, and religious themes in various locations.
# Cluster 1: Candlelight Concert Reviews - Reviews and information about candlelight concerts in different locations and venues.
# Cluster 19: Candle Events in Various Locations - Concerts and events involving candles in locations like Antwerp, Yvelines, and Besancon.
# Cluster 30: Spectacles in Multiple Cities - Spectacles and events in Lyon, Marseille, Toulouse, and other cities with specific dates.
# Cluster 3: Diverse Candlelight Concerts - Various candlelight events and concerts in different locations with specific performers.
# Cluster 21: Classical Candlelight Concerts - Classical music concerts in various cities featuring candlelight settings.
# Cluster 2: City Candlelight Events - Candlelight events in different cities for various years.
# Cluster 22: Fever Candlelight - Keywords related to a website or event called 'Fever' with mentions of candlelight.
# Cluster 10: Tribute Candlelight Events - Candlelight events paying tribute to various musicians at different venues and dates.
# Cluster 5: Candlelight Experiences - Keywords related to candlelight experiences, photos, and events.
# Cluster 4: Candlelight Events - Events and experiences centered around candlelight ambiance.
# Cluster 28: Evening Activities in Paris - Activities and events to enjoy in Paris during the evening.
# Cluster 8: Candlelight Concerts in Cities - Concerts featuring candlelight ambiance held in various cities.
# Cluster 25: Hans Zimmer Candlelight Events - Events related to Hans Zimmer, potentially candlelight concerts.
# Cluster 23: Fever Candlelight Events - Candlelight events organized by Fever.
# Cluster 20: Christmas Concerts in France - Upcoming Christmas concerts in Paris, Avignon, Strasbourg, and Toulouse.
# Cluster 24: Candlelight Events Worldwide - Candlelight events happening in Fourviere, Brest, Como, Alicante, and London.
# Cluster 18: Montreal & Paris Concerts - Concerts in Montreal and Paris, including Christmas concerts and Candlelight events at the Eiffel Tower.
# Cluster 11: Misspelled Candlelight Keywords - Keywords related to 'candlelight' with common misspellings.
# Cluster 12: Candlelight Concerts with Coldplay - Candlelight concerts featuring Coldplay and Imagine Dragons in Paris, Bordeaux, Nantes, and Lyon.
# Cluster 29: Valentine's Day Events 2024-2025 - Upcoming Valentine's Day events in Strasbourg, Paris, Brest, Limoges for the years 2024 and 2025.
# Cluster 16: Paris Live Music Bars - Bars and clubs in Paris with live music performances, including classical and various music genres.
# Cluster 17: Piano Concerts in Multiple Cities - Concerts featuring piano performances in Avignon, Paris, Toulouse, Nantes, Grenoble, Strasbourg, Lille, Saint Etienne, Brussels, with some events involving candles.
# Cluster 13: Halloween Events 2024 - Halloween events in Brest, Nantes, Luxembourg, Bordeaux, Copenhagen for the year 2024, including themed drawings and parties.
# Cluster 14: Coldplay Candlelight Tributes - Candlelight tribute events featuring music by Coldplay in Brest, Salerno, Evian for the years 2024 and 2025.
# Cluster 9: Classical Candlelight Music Events - Events featuring classical music performed by candlelight.
# Cluster 6: Bridgerton Candlelight Events - Candlelight events inspired by the TV show Bridgerton.
# Cluster 15: Coldplay Concerts in Lyon 2024 - Upcoming Coldplay concerts scheduled in Lyon for 2024.
# Cluster 26: Spanish Candlelight Concerts - Candlelight concerts taking place in various cities in Spain.
# Cluster 7: Hans Zimmer Candlelight Events - Candlelight events featuring music by composer Hans Zimmer.
# Calculating semantic coherence for each cluster...
# Cluster 27: Coherence = 0.468
# Cluster 1: Coherence = 0.712
# Cluster 19: Coherence = 0.637
# Cluster 30: Coherence = 0.532
# Cluster 3: Coherence = 0.619
# Cluster 21: Coherence = 0.691
# Cluster 2: Coherence = 0.638
# Cluster 22: Coherence = 0.821
# Cluster 10: Coherence = 0.329
# Cluster 5: Coherence = 0.815
# Cluster 4: Coherence = 0.674
# Cluster 28: Coherence = 0.753
# Cluster 8: Coherence = 0.795
# Cluster 25: Coherence = 0.738
# Cluster 23: Coherence = 0.799
# Cluster 20: Coherence = 0.739
# Cluster 24: Coherence = 0.765
# Cluster 18: Coherence = 0.514
# Cluster 11: Coherence = 0.660
# Cluster 12: Coherence = 0.568
# Cluster 29: Coherence = 0.848
# Cluster 16: Coherence = 0.666
# Cluster 17: Coherence = 0.692
# Cluster 13: Coherence = 0.752
# Cluster 14: Coherence = 0.769
# Cluster 9: Coherence = 0.603
# Cluster 6: Coherence = 0.751
# Cluster 15: Coherence = 0.759
# Cluster 26: Coherence = 0.791
# Cluster 7: Coherence = 0.810
# ✅ Semantic clustering complete! Results saved to 'semantic_clustered_keywords.csv'.
#
# Clustering Summary:
# Cluster 27: Religious Candlelight Concerts - 1166 keywords (Coherence: 0.468)
#   Representative keywords:
#     - billetterie nuits de fourvière
#     - bougie merignac eglise
#     - candlelight casse-noisette: hommage à tchaïkovski, victoria hall, 21 décembre
#     - événement belgique aujourd'hui
#     - magasin bougie rennes
# Cluster 1: Candlelight Concert Reviews - 1629 keywords (Coherence: 0.712)
#   Representative keywords:
#     - candlelight concert brest
#     - candlelight concert brugge
#     - candlelight concert brugge 2023
#     - candlelight concert como
#     - candlelight concert locations
# Cluster 19: Candle Events in Various Locations - 1069 keywords (Coherence: 0.637)
#   Representative keywords:
#     - concert 1000 bougies
#     - concert a la bougies
#     - concert anvers 2024
#     - concert aux bougies
#     - concert avec bougies
# Cluster 30: Spectacles in Multiple Cities - 472 keywords (Coherence: 0.532)
#   Representative keywords:
#     - cinema pharo marseille
#     - spectacle 31 décembre 2024 lyon
#     - spectacle bougie bordeaux
#     - spectacle bougie marseille
#     - spectacle bougie strasbourg
# Cluster 3: Diverse Candlelight Concerts - 1036 keywords (Coherence: 0.619)
#   Representative keywords:
#     - candlelight beloeil
#     - candlelight brescia
#     - candlelight brescia 2024
#     - candlelight c'est quoi
#     - candlelight concett
# Cluster 21: Classical Candlelight Concerts - 559 keywords (Coherence: 0.691)
#   Representative keywords:
#     - concert a la bougie aix en provence
#     - concert à la bougie aix en provence
#     - concert a la bougie marseille
#     - concert à la bougie marseille
#     - concert aix en provence aujourd'hui
# Cluster 2: City Candlelight Events - 804 keywords (Coherence: 0.638)
#   Representative keywords:
#     - brest candlelight
#     - candlelight avignon
#     - candlelight avignon 2023
#     - candlelight avignon 2024
#     - candlelight avignon 2025
# Cluster 22: Fever Candlelight - 374 keywords (Coherence: 0.821)
#   Representative keywords:
#     - 2024 fever
#     - candle.light fever
#     - de fever
#     - fever
#     - fever 2023
# Cluster 10: Tribute Candlelight Events - 722 keywords (Coherence: 0.329)
#   Representative keywords:
#     - candlelight : hommage à abba, institut océanographique de paris, 31 août
#     - candlelight : hommage à hans zimmer, institut océanographique de paris, 23 février
#     - candlelight : hommage à ludovico einaudi
#     - candlelight : hommage à ludovico einaudi, chapelle de la trinité, 12 janvier
#     - candlelight : hommage à ludovico einaudi, chapelle de la trinité, 16 décembre
# Cluster 5: Candlelight Experiences - 304 keywords (Coherence: 0.815)
#   Representative keywords:
#     - candle in light
#     - càndle light
#     - candle light 2023
#     - candle light 2024
#     - candle light 2025
# Cluster 4: Candlelight Events - 740 keywords (Coherence: 0.674)
#   Representative keywords:
#     - candlelight 20%
#     - candlelight 2024
#     - candlelight experience.com
#     - candlelight la.rochelle
#     - candlelight photo
# Cluster 28: Evening Activities in Paris - 312 keywords (Coherence: 0.753)
#   Representative keywords:
#     - que faire ce soir a paris
#     - que faire ce soir à paris
#     - que faire ce soir paris
#     - quoi faire ce soir a paris
#     - que faire à paris ce soir
# Cluster 8: Candlelight Concerts in Cities - 255 keywords (Coherence: 0.795)
#   Representative keywords:
#     - candle light konzert düsseldorf
#     - candle light konzert erfurt
#     - candlelight konzert düsseldorf
#     - candlelight konzert karlsruhe heute
#     - candlelight konzert köln
# Cluster 25: Hans Zimmer Candlelight Events - 237 keywords (Coherence: 0.738)
#   Representative keywords:
#     - candelight hans zimmer
#     - candellight hans zimmer
#     - candlight hans zimmer
#     - hans zimmer 2024 fnac
#     - hans zimmer abbaye de l'epau
# Cluster 23: Fever Candlelight Events - 311 keywords (Coherence: 0.799)
#   Representative keywords:
#     - fever by candlelight
#     - fever candlelight
#     - fever candlelight 2024
#     - fever candlelight 2025
#     - fever candlelight events
# Cluster 20: Christmas Concerts in France - 204 keywords (Coherence: 0.739)
#   Representative keywords:
#     - concert de noël 2024 paris
#     - concert de noel avignon
#     - concert de noel paris
#     - concert de noel strasbourg
#     - concert de noël strasbourg
# Cluster 24: Candlelight Events Worldwide - 422 keywords (Coherence: 0.765)
#   Representative keywords:
#     - candelaight
#     - candelaigth
#     - candeleight
#     - candelighg
#     - candelighit
# Cluster 18: Montreal & Paris Concerts - 193 keywords (Coherence: 0.514)
#   Representative keywords:
#     - candlelight concert oxford tickets
#     - candlelight concert tour eiffel
#     - christmas concert paris
#     - christmas concert paris 2023
#     - christmas concert paris 2024
# Cluster 11: Misspelled Candlelight Keywords - 177 keywords (Coherence: 0.660)
#   Representative keywords:
#     - cande light
#     - cander light
#     - candke light
#     - candl light
#     - candla light
# Cluster 12: Candlelight Concerts with Coldplay - 151 keywords (Coherence: 0.568)
#   Representative keywords:
#     - candlelight : coldplay vs imagine dragons
#     - candlelight : coldplay vs imagine dragons, chapelle de la trinité, 29 janvier
#     - candlelight bordeaux coldplay imagine dragons
#     - candlelight coldplay vs imagine dragons
#     - candlelight coldplay vs imagine dragons lille
# Cluster 29: Valentine's Day Events 2024-2025 - 99 keywords (Coherence: 0.848)
#   Representative keywords:
#     - image de saint valentin 2024
#     - image saint valentin 2024
#     - images saint valentin 2024
#     - photo saint valentin 2024
#     - saint valentin 2024 image
# Cluster 16: Paris Live Music Bars - 308 keywords (Coherence: 0.666)
#   Representative keywords:
#     - tout le monde debout musique classique concert
#     - bar musique live paris
#     - musique live paris ce soir
#     - bar avec musique live paris
#     - bar avec musique paris
# Cluster 17: Piano Concerts in Multiple Cities - 181 keywords (Coherence: 0.692)
#   Representative keywords:
#     - concert piano avignon
#     - concert piano bougie paris
#     - concert piano bougie strasbourg
#     - concert piano bougie toulouse
#     - concert piano bougies
# Cluster 13: Halloween Events 2024 - 156 keywords (Coherence: 0.752)
#   Representative keywords:
#     - bordeaux halloween 2024
#     - brest halloween 2024
#     - dessins halloween
#     - halloween 2024 brest
#     - halloween 2024 luxembourg
# Cluster 14: Coldplay Candlelight Tributes - 199 keywords (Coherence: 0.769)
#   Representative keywords:
#     - candlelight brest coldplay
#     - candlelight by coldplay
#     - candlelight coldplay
#     - candlelight coldplay 2024
#     - candlelight coldplay 2025
# Cluster 9: Classical Candlelight Music Events - 212 keywords (Coherence: 0.603)
#   Representative keywords:
#     - candle light classical music
#     - candlelight classical music
#     - candlelight instrumental
#     - candlelight music
#     - candlelight music london
# Cluster 6: Bridgerton Candlelight Events - 218 keywords (Coherence: 0.751)
#   Representative keywords:
#     - bridgerton candleight
#     - bridgerton x candlelight
#     - bridgerton.candlelight
#     - candlelight brest bridgerton
#     - candlelight bridgerton
# Cluster 15: Coldplay Concerts in Lyon 2024 - 150 keywords (Coherence: 0.759)
#   Representative keywords:
#     - coldplay 2024 lyon
#     - coldplay billetterie lyon
#     - coldplay concert 2024 lyon
#     - coldplay fnac lyon
#     - coldplay lyon
# Cluster 26: Spanish Candlelight Concerts - 90 keywords (Coherence: 0.791)
#   Representative keywords:
#     - concierto candlelight bilbao
#     - concierto candlelight madrid
#     - concierto candlelight malaga
#     - concierto candlelight sevilla
#     - concierto candlelight valencia
# Cluster 7: Hans Zimmer Candlelight Events - 166 keywords (Coherence: 0.810)
#   Representative keywords:
#     - candlelight biarritz hans zimmer
#     - candlelight brest hans zimmer
#     - candlelight colmar hans zimmer
#     - candlelight evian hans zimmer
#     - candlelight hans zimmer
